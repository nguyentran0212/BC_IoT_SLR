# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
"""
This method splits the strings in RQs into a list of items.

These items can be areas and subareas of research.
"""

def split_areas(input_data, lv1_sep = ";"):
    areas = input_data.split(lv1_sep)
    areas = [area.strip().title() for area in areas]
    return areas

def _split_sub_areas(input_data, lv2_sep = ",", area_sub_sep = ":"):
    split_result = input_data.split(lv2_sep)
    if len(split_result) == 1:
        return [input_data.strip()]
    else:
        sub_areas = []
        area_name = split_result[0].split(area_sub_sep)[0].strip()
        # The first item has the format area:subarea, while the rest does not have area.
        # Try to split the string by : and grab the second part.
        # If it is possible, then we are processing the first element.
        # If we have error, it means we are processing the rest of the elements.
        for sub in split_result:
            try:
                sub_areas.append("%s:%s" % (area_name, sub.split(area_sub_sep)[1].strip().lower()))
            except IndexError:
                sub_areas.append("%s:%s" % (area_name, sub.strip().lower()))
        return sub_areas
    
def split_sub_areas(input_data, lv2_sep = ",", area_sub_sep = ":"):
    split_result = input_data.split(lv2_sep)
    sub_areas = []
    
    # Set the area name only if we can find the colon
    area_name = ""
    if split_result[0].find(":") != -1:
        area_name = split_result[0].split(area_sub_sep)[0].strip()
        
    for sub in split_result:
        sub_area = ""
        
        # The first item has the format area:subarea, while the rest does not have area.
        # Try to split the string by : and grab the second part.
        # If it is possible, then we are processing the first element.
        # If we have error, it means we are processing the rest of the elements.
        try:
            sub_area = sub.split(area_sub_sep)[1].strip().title()
            
        except IndexError:
            sub_area = sub.strip().title()        
        # Return the sub_area as is if there is no area name
        if area_name == "":
            sub_areas.append(sub_area)
        else:
            sub_areas.append("%s:%s" % (area_name, sub_area))
        
    return sub_areas

def split_input_data(input_data, split_areas = split_areas, split_sub_areas = split_sub_areas):
    results = []
    areas = split_areas(input_data)
    for area in areas:
        results.extend(split_sub_areas(area))
    return results

# %%
"""
Create relation between papers and values of an RQ
"""

def create_relation_paper_RQ(raw_df, rq_name_in_df, rq_display_name, split_sub_areas = True):
    # prepare an empty data frame
    paper_ids = []
    titles = []
    years = []
    venues = []
    types = []
    problem_areas = []
    data = {
        "Paper ID" : paper_ids,
        "Title" : titles,
        "Year" : years,
        "Venue" : venues,
        "Type" : types,
        rq_display_name : problem_areas
    }

    # apply text split
    if split_sub_areas:
        rq_lists = raw_df[rq_name_in_df].apply(split_input_data)
    else:
        rq_lists = raw_df[rq_name_in_df].apply(split_areas)
    

    # construct the data frame
    for i in range(len(rq_lists)):
        for rq_value in rq_lists[i]:
            paper_ids.append(raw_df["Paper ID"][i])
            titles.append(raw_df["Title"][i])
            years.append(raw_df["Year"][i])
            venues.append(raw_df["Venue"][i])
            types.append(raw_df["Type"][i])
            problem_areas.append(rq_value)


    paper_rq_relation = pd.DataFrame(data)
    paper_rq_relation.sort_values(rq_display_name)
    return paper_rq_relation

# %%
def draw_countplot(data, column, size = (10, 8), font = 12, fig_name = "fig"):
    sns.countplot(y = column, data = data, orient="v", palette="coolwarm", 
              order = data[column].value_counts().index)
    ax1 = plt.gca()
    ax1.yaxis.label.set_visible(False)
    ax1.xaxis.label.set_visible(False)
    plt.rcParams.update({"font.size": font})
    fig = plt.gcf()
    fig.set_size_inches(*size)
    for i, v in enumerate(data[column].value_counts()):
        ax1.text(v, i, " "+str(v), color='0.75', va='center', fontweight='bold')
    plt.show()
    fig.savefig(fig_name + ".pdf", bbox_inches='tight')

# %%
"""
Creating relations between two RQs
"""

def create_relation(data, column_A_in_df, column_A_display, column_B_in_df, column_B_display):
    column_A_lists = data[column_A_in_df].apply(split_input_data)
    column_B_lists = data[column_B_in_df].apply(split_input_data)

    relations_list = []
    for i in range(len(column_A_lists)):
        column_A_values = column_A_lists[i]
        column_B_values = column_B_lists[i]
        for column_A_value in column_A_values:
            for column_B_value in column_B_values:
                relations_list.append((column_A_value, column_B_value))
    
    # Create data frame. Each column holds items from one RQ
    A, B = zip(*relations_list)
    data = {
        column_A_display : A,
        column_B_display : B
    }
    return pd.DataFrame(data)

# %%
import networkx as nx

def load(df):
    G = nx.Graph()
    count = 0
    for row in df.iterrows():
        node_A = row[1][0]
        node_B = row[1][1]
        if G.has_edge(node_A, node_B):
            # we added this one before, just increase the weight by one
            G[node_A][node_B]['weight'] += 1
        else:
            # new edge. add with weight=1
            G.add_edge(node_A, node_B, weight=1)
        count += 1
        """
        if count == 5:
            break
        """
    return G

# %%
"""
Loads the extracted data for RQ1
"""

raw_path = "Round 2/RQ1_Round2_0.0.1.xlsx"

raw_df = pd.read_excel(raw_path)
raw_df.head()
# Out:
#            Paper ID                                              Title  Year  \
# 0      Zhang:2015:1  An IoT Electric Business Model Based on the Pr...  2015
# 1      Ouaddah:2016  FairAccess: a new Blockchain-based access cont...  2016
# 2  Samaniego:2016:1  Using blockchain to push software-defined IoT ...  2016
# 3        Ali:2017:1  The quest for fully smart autonomous business ...  2017
# 4        Ali:2017:2          IoT data privacy via blockchains and IPFS  2017
#
#                                             Venue        Type  \
# 0                                       ICIN 2015  Conference
# 1             Security and Communication Networks     Journal
# 2  ACM International Conference Proceeding Series  Conference
# 3  ACM International Conference Proceeding Series  Conference
# 4  ACM International Conference Proceeding Series  Conference
#
#                                Improvement Objective  \
# 0  Support the ownership and exchange of resource...
# 1  Security: confidentiality, integrity, authenti...
# 2  Performance: Time behaviour; Orchestrate proce...
# 3                       Enable IoT Service Discovery
# 4               Security: integrity, confidentiality
#
#        Improvement Objective Category  \
# 0  Improve Quality; New Functionality
# 1                     Improve Quality
# 2  Improve Quality; New Functionality
# 3                   New Functionality
# 4                     Improve Quality
#
#                                    Technical Problem  \
# 0  Control and incentivize M2M trading; Protect r...
# 1  Decentralize the access control to and from de...
# 2  Decentralize the control of processes within a...
# 3  Decentralize the management of identity and ce...
# 4  Decentralize the access control to data and se...
#
#                           Technical Problem Category
# 0  Control and incentivize exchanges in IoT syste...
# 1    Decentralize security operations of IoT systems
# 2             Decentralize operations of IoT systems
# 3  Decentralize security operations of IoT system...
# 4  Decentralize security operations of IoT system...

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Paper ID                        122 non-null    object
#  1   Title                           122 non-null    object
#  2   Year                            122 non-null    object
#  3   Venue                           122 non-null    object
#  4   Type                            122 non-null    object
#  5   Improvement Objective           122 non-null    object
#  6   Improvement Objective Category  122 non-null    object
#  7   Technical Problem               122 non-null    object
#  8   Technical Problem Category      122 non-null    object
# dtypes: object(9)
# memory usage: 8.7+ KB

# %%
"""
Countplot of specific improve objective
"""
paper_imp_obj_relation = create_relation_paper_RQ(raw_df, "Improvement Objective", "Improvement Objective")

draw_countplot(paper_imp_obj_relation, "Improvement Objective", size = (8.5,6), font = 12, fig_name = "RQ1_improvement_objectives")

# %%
"""
Countplot of groups of improve objective
"""
paper_imp_cate_relation = create_relation_paper_RQ(raw_df, "Improvement Objective Category", "a")
#paper_imp_cate_relation["a"]
draw_countplot(paper_imp_cate_relation, "a", size = (10,1), fig_name = "RQ1_quality_vs_functionality")
#paper_imp_obj_relation.info()

# %%
"""
Countplot of technical issues
"""
paper_tech_prob_relation = create_relation_paper_RQ(raw_df, "Technical Problem", "Technical Problem")
draw_countplot(paper_tech_prob_relation, "Technical Problem", size = (8, 7.5), font = 12, fig_name = "RQ1_problems")

# %%
"""
Countplot of technical problem categories
"""
paper_prob_cate_relation = create_relation_paper_RQ(raw_df, "Technical Problem Category", "Technical Problem Category")
draw_countplot(paper_prob_cate_relation, "Technical Problem Category", size = (9,2.5), fig_name = "RQ1_problem_categories")

# %%
"""
Create relation between RQ1: Problem area, and RQ1: Technical issues
"""
relation_df = create_relation(data = raw_df, column_A_in_df = "Improvement Objective", column_A_display = "Improvement Objective", column_B_in_df = "Technical Problem Category", column_B_display = "Technical Problem Category")
#relation_df.groupby(["Improvement Objective", 'Technical Problem Category']).size()

def categoryToNumerical(df, series_name):
    df[series_name] = df[series_name].astype("category")
    df[series_name + " Cat"] = relation_df[series_name].cat.codes

categoryToNumerical(relation_df, "Improvement Objective")
categoryToNumerical(relation_df, "Technical Problem Category")
relation_df["Technical Problem Category"].cat.categories
# Out:
# Index(['Build Trusted Communication Channels',
#        'Control And Incentivize Exchanges In Iot Systems',
#        'Decentralize Operations Of Iot Systems',
#        'Decentralize Security Operations Of Iot Systems',
#        'Ensure The Integrity Of Data And Services In Iot Systems'],
#       dtype='object')

# %%
"""
Loads the extracted data for RQ2_1
"""

raw_path = "Round 2/extraction_Q2_Q3_v1.1.0.xlsx"

raw_df = pd.read_excel(raw_path)
raw_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-23190c7bbd86> in <module>
#       5 raw_path = "Round 2/extraction_Q2_Q3_v1.0.0.xlsx"
#       6
# ----> 7 raw_df = pd.read_excel(raw_path)
#       8 raw_df.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# --> 821         self._reader = self._engines[engine](self._io)
#     822
#     823     def __fspath__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Round 2/extraction_Q2_Q3_v1.0.0.xlsx'

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 7 columns):
# Paper ID                           90 non-null object
# Title                              90 non-null object
# Year                               90 non-null int64
# Venue                              90 non-null object
# Type                               90 non-null object
# Affected Modules in IoT Systems    90 non-null object
# Deployment of Blockchain           90 non-null object
# dtypes: int64(1), object(6)
# memory usage: 5.0+ KB

# %%
"""
Countplot of deployment pattern
"""
paper_deployment_relation = create_relation_paper_RQ(raw_df, "Deployment of Blockchain", "Deployment", split_sub_areas = False)

draw_countplot(paper_deployment_relation, "Deployment", size = (10,4), fig_name = "RQ2_deployment")

# %%
"""
Countplot of affected modules in IoT systems
"""
paper_module_relation = create_relation_paper_RQ(raw_df, "Affected Modules in IoT Systems", "Affected Modules", split_sub_areas = False)

draw_countplot(paper_module_relation, "Affected Modules", size = (10,8.5), fig_name = "RQ2_affected_modules")

# %%
"""
Loads the extracted data for RQ2_2 on on and off chain data and logic
"""

raw_path = "RQ2_RQ3/extraction_Q2_Q3_v1.0.0.xlsx"

raw_df = pd.read_excel(raw_path, sheet_name="RQ2.2")
raw_df["Off-chain data"] = raw_df["Off-chain data"].fillna("No off-chain data")
raw_df["On-chain logic"] = raw_df["On-chain logic"].fillna("No on-chain logic")
raw_df["Off-chain logic"] = raw_df["Off-chain logic"].fillna("No Off-chain logic")
raw_df
# Out:
#                  Paper ID                                              Title  \
# 0            Zhang:2015:1  An IoT Electric Business Model Based on the Pr...
# 1            Ouaddah:2016  FairAccess: a new Blockchain-based access cont...
# 2        Samaniego:2016:1  Using blockchain to push software-defined IoT ...
# 3              Ali:2017:1  The quest for fully smart autonomous business ...
# 4              Ali:2017:2          IoT data privacy via blockchains and IPFS
# 5        Boudguiga:2017:1  Towards better availability and accountability...
# 6             Daza:2017:1  CONNECT: CONtextual NamE disCovery for blockch...
# 7            Dorri:2017:2            Towards an optimized blockchain for IoT
# 8             Kaga:2017:1  A secure and practical signature scheme for bl...
# 9              Lee:2017:1  Blockchain-based secure firmware update for em...
# 10              Li:2017:1  A blockchain based new secure multi-layer netw...
# 11           Liang:2017:1  Towards data assurance and resilience in IoT u...
# 12             Liu:2017:1  Blockchain Based Data Integrity Service Framew...
# 13       Lundqvist:2017:1  Thing-to-thing electricity micro payments usin...
# 14         Missier:2017:1  Mind My Value: A decentralized infrastructure ...
# 15         Shafagh:2017:1  Towards blockchain-based auditable storage and...
# 16             Xie:2017:1  Secured Data Storage Scheme Based on Block Cha...
# 17             Zhu:2017:1  Autonomic Identity Framework for the Internet ...
# 18        Afanasev:2018:1  A Design of Cyber-physical Production System P...
# 19         Agrawal:2018:1        Continuous Security in IoT Using Blockchain
# 20         Alphand:2018:1  IoTChain: A blockchain security architecture f...
# 21           Angin:2018:1  A blockchain-based decentralized security arch...
# 22          Ayoade:2018:1  Decentralized IoT data management using blockc...
# 23          Biswas:2018:1  A Scalable Blockchain Framework for Secure Tra...
# 24             Cha:2018:1  A Blockchain Connected Gateway for BLE-Based D...
# 25            Choi:2018:1       A Blockchain-based Secure IoT Control Scheme
# 26           Danzi:2018:1  Analysis of the communication traffic for bloc...
# 27        DiPietro:2018:1  A blockchain-based trust system for the intern...
# 28       Dukkipati:2018:1  Decentralized, blockchain based access control...
# 29           Ellul:2018:1  AlkylVM: A Virtual Machine for Smart Contract ...
# ..                    ...                                                ...
# 60              Qi:2018:1  QoS-driven adaptive trust service coordination...
# 61             Qiu:2018:1  Blockchain-Based Software-Defined Industrial I...
# 62              Qu:2018:1  A hypergraph-based blockchain model and applic...
# 63              Qu:2018:2  Blockchain based credibility verification meth...
# 64  Rahulamathavan:2018:1  Privacy-preserving blockchain based IoT ecosys...
# 65            Rifi:2018:1  Towards using blockchain technology for IoT da...
# 66            Ruta:2018:1  A Blockchain Infrastructure for the Semantic W...
# 67       Samaniego:2018:1          Zero-Trust Hierarchical Management in IoT
# 68     Sanseverino:2018:1  The blockchain in microgrids for transacting e...
# 69       Saravanan:2018:1  SMEAD: A secured mobile enabled assisting devi...
# 70          Sharma:2018:1  A Software Defined Fog Node Based Distributed ...
# 71          Sharma:2018:2  Blockchain based hybrid network architecture f...
# 72          Sharma:2018:3  Energy-Efficient Distributed Network Architect...
# 73           Singh:2018:1  Trust Bit: Reward-based intelligent vehicle co...
# 74      Spathoulas:2018:1  Towards Reliable Integrity in Blacklisting: Fa...
# 75             Sun:2018:1  Using ethereum blockchain in Internet of Thing...
# 76           Tapas:2018:1  Blockchain-Based IoT-cloud authorization and d...
# 77           Uddin:2018:1  Continuous Patient Monitoring with a Patient C...
# 78            Wang:2018:1  A Blockchain Based Privacy-Preserving Incentiv...
# 79             Wen:2018:1  Evidence and trust: IoT Collaborative security...
# 80              Wu:2018:1  An Out-of-band Authentication Scheme for Inter...
# 81           Xiong:2018:1        When mobile blockchain meets edge computing
# 82              Xu:2018:1  A blockchain-based storage system for data ana...
# 83            Yang:2018:1  Smart-toy-edge-computing-oriented data exchang...
# 84            Yang:2018:2  Blockchain-based Decentralized Trust Managemen...
# 85            Yang:2018:3  A blockchain-based reputation system for data ...
# 86           Zhang:2018:1  SMER: a secure method of exchanging resources ...
# 87           Zhang:2018:2  Smart Contract-Based Access Control for the In...
# 88            Zhou:2018:1  BeeKeeper: A Blockchain-Based IoT System with ...
# 89          Zouari:2018:1  Privacy Preserving Profile Matching Protocol f...
#
#     Year                                              Venue          Type  \
# 0   2015                                          ICIN 2015    Conference
# 1   2016                Security and Communication Networks       Journal
# 2   2016     ACM International Conference Proceeding Series    Conference
# 3   2017     ACM International Conference Proceeding Series    Conference
# 4   2017     ACM International Conference Proceeding Series    Conference
# 5   2017  Proceedings of the 2nd IEEE European Symposium...      Workshop
# 6   2017  Proceedings of IEEE International Conference o...    Conference
# 7   2017  Proceedings of the 2nd International Conferenc...    Conference
# 8   2017  Lecture Notes in Computer Science (including s...       Journal
# 9   2017                          Journal of Supercomputing       Journal
# 10  2017  Proceedings of the 2nd IEEE International Cong...    Conference
# 11  2017  Proceedings of IEEE Military Communications Co...    Conference
# 12  2017  Proceedings of the IEEE 24th International Con...    Conference
# 13  2017  Proceedings of the Global Internet of Things S...    Conference
# 14  2017     ACM International Conference Proceeding Series    Conference
# 15  2017  Proceedings of the 2017 Cloud Computing Securi...      Workshop
# 16  2017  Proceedings of the 3rd International Conferenc...    Conference
# 17  2017  Proceedings of the IEEE International Conferen...    Conference
# 18  2018  Proceedings of the 22nd Conference of Open Inn...    Conference
# 19  2018  Proceedings of the IEEE International Conferen...    Conference
# 20  2018  Proceedings of the IEEE Wireless Communication...    Conference
# 21  2018  Lecture Notes in Computer Science (including s...       Journal
# 22  2018  Proceedings of the 19th IEEE International Con...    Conference
# 23  2018                    IEEE Internet of Things Journal       Journal
# 24  2018                                        IEEE Access       Journal
# 25  2018  Proceedings of the International Conference on...    Conference
# 26  2018    IEEE International Conference on Communications    Conference
# 27  2018  Proceedings of ACM Symposium on Access Control...    Conference
# 28  2018  Proceedings of the 3rd ACM Workshop on Attribu...      Workshop
# 29  2018  Proceedings of the 9th IFIP International Conf...    Conference
# ..   ...                                                ...           ...
# 60  2018                              Sensors (Switzerland)       Journal
# 61  2018                    IEEE Internet of Things Journal       Journal
# 62  2018                              Sensors (Switzerland)       Journal
# 63  2018                Security and Communication Networks       Journal
# 64  2018  Proceedings of the 11th IEEE International Con...    Conference
# 65  2018  Proceedings of the 2017 IEEE 17th Internationa...    Conference
# 66  2018                   Proceedings of the CEUR Workshop      Workshop
# 67  2018  Proceedings of the IEEE International Congress...    Conference
# 68  2018  Proceedings of the IEEE International Conferen...    Conference
# 69  2018  Procedings of the 11th IEEE International Conf...    Conference
# 70  2018                                        IEEE Access       Journal
# 71  2018                 Future Generation Computer Systems       Journal
# 72  2018                       IEEE Communications Magazine       Journal
# 73  2018  Proceedings of the IEEE World Forum on Interne...    Conference
# 74  2018  Proceedings of the Innovations in Intelligent ...    Conference
# 75  2018  Lecture Notes in Computer Science (including s...    Conference
# 76  2018  Proceedings of the IEEE International Conferen...    Conference
# 77  2018                                        IEEE Access       Journal
# 78  2018                                        IEEE Access       Journal
# 79  2018  Proceedings of the 8th International Conferenc...    Conference
# 80  2018  Proceedings of the International Conference on...    Conference
# 81  2018                       IEEE Communications Magazine       Journal
# 82  2018              Studies in Computational Intelligence  Book chapter
# 83  2018                    Journal of Systems Architecture       Journal
# 84  2018                    IEEE Internet of Things Journal       Journal
# 85  2018  Procedings of the IEEE International Symposium...    Conference
# 86  2018                      Frontiers of Computer Science       Journal
# 87  2018                    IEEE Internet of Things Journal       Journal
# 88  2018                                        IEEE Access       Journal
# 89  2018  Proceedings of the IEEE 27th International Con...    Conference
#
#                                         On-chain data  \
# 0                           Resource exchange records
# 1                Authorisation requests and responses
# 2                         Service interaction records
# 3   Service interaction records; Device interactio...
# 4   Sensor Reading Hashes; Authorisation policies;...
# 5                          Firmware Hash (and Binary)
# 6                                Service descriptions
# 7   Device interaction records; \nService interact...
# 8                          Device interaction records
# 9                          Firmware Hash (and Binary)
# 10  Sensor Readings; Device configurations; Device...
# 11         Commands to devices; Sensor Reading Hashes
# 12                              Sensor Reading Hashes
# 13                          Resource exchange records
# 14                          Resource exchange records
# 15      Sensor Reading Hashes; Authorisation policies
# 16                                    Sensor Readings
# 17                    Device description and identity
# 18                                    Sensor readings
# 19                         Device interaction records
# 20               Authorisation requests and responses
# 21                          Resource exchange records
# 22  Sensor Reading Hashes; Authorisation requests ...
# 23        Device interaction records; sensor readings
# 24                             Authorisation policies
# 25                         Device interaction records
# 26                          Resource exchange records
# 27                          Resource exchange records
# 28               Authorisation requests and responses
# 29                         Device interaction records
# ..                                                ...
# 60                         Trust ratings; QoS ratings
# 61                                    SDN Flow Tables
# 62                         Device interaction records
# 63  Service descriptions;\nDevice description and ...
# 64                                    Sensor Readings
# 65                              Sensor Reading Hashes
# 66                               Service descriptions
# 67                                    Sensor readings
# 68                          Resource exchange records
# 69               Authorisation requests and responses
# 70  Service Descriptions; Service interaction reco...
# 71                        Service interaction records
# 72                                    SDN Flow Tables
# 73                                      Trust ratings
# 74  Whitelisted / Blacklisted  IP address; Securit...
# 75                          Resource exchange records
# 76               Authorisation requests and responses
# 77                                    Sensor Readings
# 78                          Resource exchange records
# 79  Sensor Reading Hashes; Firmware Hash (and Binary)
# 80                             Authentication records
# 81                          Resource exchange records
# 82                                    Sensor Readings
# 83                          Resource exchange records
# 84                                      Trust ratings
# 85                                      Trust ratings
# 86  Resource exchange records; Service interaction...
# 87               Authorisation requests and responses
# 88       Sensor Readings; Service interaction records
# 89                               Service descriptions
#
#                Off-chain data  \
# 0           No off-chain data
# 1           No off-chain data
# 2           No off-chain data
# 3   Smart contract repository
# 4           No off-chain data
# 5           No off-chain data
# 6           No off-chain data
# 7           No off-chain data
# 8           No off-chain data
# 9             Firmware Binary
# 10          No off-chain data
# 11          No off-chain data
# 12          No off-chain data
# 13          No off-chain data
# 14          No off-chain data
# 15          No off-chain data
# 16          No off-chain data
# 17          No off-chain data
# 18          No off-chain data
# 19          No off-chain data
# 20          No off-chain data
# 21          No off-chain data
# 22          No off-chain data
# 23          No off-chain data
# 24          No off-chain data
# 25          No off-chain data
# 26          No off-chain data
# 27          No off-chain data
# 28          No off-chain data
# 29          No off-chain data
# ..                        ...
# 60          No off-chain data
# 61          No off-chain data
# 62          No off-chain data
# 63          No off-chain data
# 64          No off-chain data
# 65          No off-chain data
# 66          No off-chain data
# 67          No off-chain data
# 68          No off-chain data
# 69          No off-chain data
# 70          No off-chain data
# 71          No off-chain data
# 72          No off-chain data
# 73          No off-chain data
# 74          No off-chain data
# 75          No off-chain data
# 76          No off-chain data
# 77          No off-chain data
# 78          No off-chain data
# 79          No off-chain data
# 80          No off-chain data
# 81          No off-chain data
# 82          No off-chain data
# 83          No off-chain data
# 84          No off-chain data
# 85          No off-chain data
# 86          No off-chain data
# 87          No off-chain data
# 88          No off-chain data
# 89          No off-chain data
#
#                                        On-chain logic  \
# 0                                   No on-chain logic
# 1                                   No on-chain logic
# 2                                   No on-chain logic
# 3                                    Business process
# 4     Authorisation mechanism; Data index maintenance
# 5                                   No on-chain logic
# 6                                   No on-chain logic
# 7                                   No on-chain logic
# 8                                   No on-chain logic
# 9                                   No on-chain logic
# 10                                  No on-chain logic
# 11                                  No on-chain logic
# 12                             Data index maintenance
# 13                                  No on-chain logic
# 14  Contract between resource providers and consumers
# 15                                  No on-chain logic
# 16                                  No on-chain logic
# 17                                  No on-chain logic
# 18  Fund distribution mechanism; digital-twin of d...
# 19                            Authorisation mechanism
# 20                            Authorisation mechanism
# 21                                  No on-chain logic
# 22                            Authorisation mechanism
# 23                                  No on-chain logic
# 24                            Digital-twin of devices
# 25                            Digital-twin of devices
# 26                                  No on-chain logic
# 27                                  No on-chain logic
# 28                            Authorisation mechanism
# 29                            Digital-twin of devices
# ..                                                ...
# 60                                  No on-chain logic
# 61                                  No on-chain logic
# 62                                  No on-chain logic
# 63                                  No on-chain logic
# 64                                  No on-chain logic
# 65                         Publish-subscribe protocol
# 66                      Service Matchmaking mechanism
# 67                                  No on-chain logic
# 68                                  No on-chain logic
# 69                            Authorisation mechanism
# 70                              Matchmaking mechanism
# 71                                  No on-chain logic
# 72                                  No on-chain logic
# 73                                  No on-chain logic
# 74                       Reputation score calculation
# 75  Contract between resource providers and consum...
# 76                            Authorisation mechanism
# 77                                  No on-chain logic
# 78  Contract between resource providers and consumers
# 79                                  No on-chain logic
# 80                                  No on-chain logic
# 81                                  No on-chain logic
# 82    Data index maintenance; Authorisation mechanism
# 83                                  No on-chain logic
# 84                                  No on-chain logic
# 85                                  No on-chain logic
# 86  Contract between resource providers and consum...
# 87                            Authorisation mechanism
# 88  Contract between resource providers and consum...
# 89                                  No on-chain logic
#
#                                   Off-chain logic
# 0                                  Business logic
# 1                              No Off-chain logic
# 2                              No Off-chain logic
# 3   Smart contract management; IoT system adapter
# 4                              No Off-chain logic
# 5                              No Off-chain logic
# 6                              No Off-chain logic
# 7                          Enforce Access Control
# 8                              No Off-chain logic
# 9                              No Off-chain logic
# 10                             No Off-chain logic
# 11                             No Off-chain logic
# 12                             No Off-chain logic
# 13                             No Off-chain logic
# 14                             No Off-chain logic
# 15                             No Off-chain logic
# 16                             No Off-chain logic
# 17                             No Off-chain logic
# 18              Device discovery; network monitor
# 19                               Trail prediction
# 20                             No Off-chain logic
# 21                             No Off-chain logic
# 22                             No Off-chain logic
# 23                        Certification Authority
# 24                          Device Authentication
# 25                             No Off-chain logic
# 26                             No Off-chain logic
# 27                             No Off-chain logic
# 28                             No Off-chain logic
# 29                             No Off-chain logic
# ..                                            ...
# 60                             No Off-chain logic
# 61                             No Off-chain logic
# 62                              Ledger Clustering
# 63                   Cryptographic key generation
# 64                             No Off-chain logic
# 65                             No Off-chain logic
# 66                               Reasoning engine
# 67                                Data publishing
# 68                             No Off-chain logic
# 69                             No Off-chain logic
# 70                             No Off-chain logic
# 71                             No Off-chain logic
# 72                             No Off-chain logic
# 73                             No Off-chain logic
# 74                             No Off-chain logic
# 75     Derive device configurations from readings
# 76                             No Off-chain logic
# 77                             No Off-chain logic
# 78                    Verify sensing data quality
# 79                             No Off-chain logic
# 80                             No Off-chain logic
# 81                             No Off-chain logic
# 82                             No Off-chain logic
# 83                             No Off-chain logic
# 84                   Reputation score calculation
# 85                   Reputation score calculation
# 86                             No Off-chain logic
# 87                             No Off-chain logic
# 88                             No Off-chain logic
# 89                             No Off-chain logic
#
# [90 rows x 9 columns]

# %%
"""
Countplot of on-chain data
"""
paper_on_chain_data_relation = create_relation_paper_RQ(raw_df, "On-chain data", "On-chain data", split_sub_areas = False)

draw_countplot(paper_on_chain_data_relation, "On-chain data", size = (10,10), fig_name = "RQ2_on_chain_data")

# %%
"""
Countplot of on-chain logic
"""


paper_on_chain_logic_relation = create_relation_paper_RQ(raw_df, "On-chain logic", "On-chain logic", split_sub_areas = False)

draw_countplot(paper_on_chain_logic_relation, "On-chain logic", size = (10,8), fig_name = "RQ2_on_chain_logic")

# %%
"""
Countplot of off-chain logic
"""


paper_on_chain_logic_relation = create_relation_paper_RQ(raw_df, "Off-chain logic", "Off-chain logic", split_sub_areas = False)

draw_countplot(paper_on_chain_logic_relation, "Off-chain logic", size = (10,10), fig_name = "RQ2_off_chain_logic")

# %%
"""
Loads the extracted data for RQ2_2 on on and off chain data and logic
"""

raw_path = "RQ2_RQ3/extraction_Q2_Q3_v1.0.0.xlsx"

raw_df = pd.read_excel(raw_path, sheet_name="RQ2.3")
raw_df
# Out:
#                  Paper ID                                              Title  \
# 0            Zhang:2015:1  An IoT Electric Business Model Based on the Pr...
# 1            Ouaddah:2016  FairAccess: a new Blockchain-based access cont...
# 2        Samaniego:2016:1  Using blockchain to push software-defined IoT ...
# 3              Ali:2017:1  The quest for fully smart autonomous business ...
# 4              Ali:2017:2          IoT data privacy via blockchains and IPFS
# 5        Boudguiga:2017:1  Towards better availability and accountability...
# 6             Daza:2017:1  CONNECT: CONtextual NamE disCovery for blockch...
# 7            Dorri:2017:2            Towards an optimized blockchain for IoT
# 8             Kaga:2017:1  A secure and practical signature scheme for bl...
# 9              Lee:2017:1  Blockchain-based secure firmware update for em...
# 10              Li:2017:1  A blockchain based new secure multi-layer netw...
# 11           Liang:2017:1  Towards data assurance and resilience in IoT u...
# 12             Liu:2017:1  Blockchain Based Data Integrity Service Framew...
# 13       Lundqvist:2017:1  Thing-to-thing electricity micro payments usin...
# 14         Missier:2017:1  Mind My Value: A decentralized infrastructure ...
# 15         Shafagh:2017:1  Towards blockchain-based auditable storage and...
# 16             Xie:2017:1  Secured Data Storage Scheme Based on Block Cha...
# 17             Zhu:2017:1  Autonomic Identity Framework for the Internet ...
# 18        Afanasev:2018:1  A Design of Cyber-physical Production System P...
# 19         Agrawal:2018:1        Continuous Security in IoT Using Blockchain
# 20         Alphand:2018:1  IoTChain: A blockchain security architecture f...
# 21           Angin:2018:1  A blockchain-based decentralized security arch...
# 22          Ayoade:2018:1  Decentralized IoT data management using blockc...
# 23          Biswas:2018:1  A Scalable Blockchain Framework for Secure Tra...
# 24             Cha:2018:1  A Blockchain Connected Gateway for BLE-Based D...
# 25            Choi:2018:1       A Blockchain-based Secure IoT Control Scheme
# 26           Danzi:2018:1  Analysis of the communication traffic for bloc...
# 27        DiPietro:2018:1  A blockchain-based trust system for the intern...
# 28       Dukkipati:2018:1  Decentralized, blockchain based access control...
# 29           Ellul:2018:1  AlkylVM: A Virtual Machine for Smart Contract ...
# ..                    ...                                                ...
# 60              Qi:2018:1  QoS-driven adaptive trust service coordination...
# 61             Qiu:2018:1  Blockchain-Based Software-Defined Industrial I...
# 62              Qu:2018:1  A hypergraph-based blockchain model and applic...
# 63              Qu:2018:2  Blockchain based credibility verification meth...
# 64  Rahulamathavan:2018:1  Privacy-preserving blockchain based IoT ecosys...
# 65            Rifi:2018:1  Towards using blockchain technology for IoT da...
# 66            Ruta:2018:1  A Blockchain Infrastructure for the Semantic W...
# 67       Samaniego:2018:1          Zero-Trust Hierarchical Management in IoT
# 68     Sanseverino:2018:1  The blockchain in microgrids for transacting e...
# 69       Saravanan:2018:1  SMEAD: A secured mobile enabled assisting devi...
# 70          Sharma:2018:1  A Software Defined Fog Node Based Distributed ...
# 71          Sharma:2018:2  Blockchain based hybrid network architecture f...
# 72          Sharma:2018:3  Energy-Efficient Distributed Network Architect...
# 73           Singh:2018:1  Trust Bit: Reward-based intelligent vehicle co...
# 74      Spathoulas:2018:1  Towards Reliable Integrity in Blacklisting: Fa...
# 75             Sun:2018:1  Using ethereum blockchain in Internet of Thing...
# 76           Tapas:2018:1  Blockchain-Based IoT-cloud authorization and d...
# 77           Uddin:2018:1  Continuous Patient Monitoring with a Patient C...
# 78            Wang:2018:1  A Blockchain Based Privacy-Preserving Incentiv...
# 79             Wen:2018:1  Evidence and trust: IoT Collaborative security...
# 80              Wu:2018:1  An Out-of-band Authentication Scheme for Inter...
# 81           Xiong:2018:1        When mobile blockchain meets edge computing
# 82              Xu:2018:1  A blockchain-based storage system for data ana...
# 83            Yang:2018:1  Smart-toy-edge-computing-oriented data exchang...
# 84            Yang:2018:2  Blockchain-based Decentralized Trust Managemen...
# 85            Yang:2018:3  A blockchain-based reputation system for data ...
# 86           Zhang:2018:1  SMER: a secure method of exchanging resources ...
# 87           Zhang:2018:2  Smart Contract-Based Access Control for the In...
# 88            Zhou:2018:1  BeeKeeper: A Blockchain-Based IoT System with ...
# 89          Zouari:2018:1  Privacy Preserving Profile Matching Protocol f...
#
#     Year                                              Venue          Type  \
# 0   2015                                          ICIN 2015    Conference
# 1   2016                Security and Communication Networks       Journal
# 2   2016     ACM International Conference Proceeding Series    Conference
# 3   2017     ACM International Conference Proceeding Series    Conference
# 4   2017     ACM International Conference Proceeding Series    Conference
# 5   2017  Proceedings of the 2nd IEEE European Symposium...      Workshop
# 6   2017  Proceedings of IEEE International Conference o...    Conference
# 7   2017  Proceedings of the 2nd International Conferenc...    Conference
# 8   2017  Lecture Notes in Computer Science (including s...       Journal
# 9   2017                          Journal of Supercomputing       Journal
# 10  2017  Proceedings of the 2nd IEEE International Cong...    Conference
# 11  2017  Proceedings of IEEE Military Communications Co...    Conference
# 12  2017  Proceedings of the IEEE 24th International Con...    Conference
# 13  2017  Proceedings of the Global Internet of Things S...    Conference
# 14  2017     ACM International Conference Proceeding Series    Conference
# 15  2017  Proceedings of the 2017 Cloud Computing Securi...      Workshop
# 16  2017  Proceedings of the 3rd International Conferenc...    Conference
# 17  2017  Proceedings of the IEEE International Conferen...    Conference
# 18  2018  Proceedings of the 22nd Conference of Open Inn...    Conference
# 19  2018  Proceedings of the IEEE International Conferen...    Conference
# 20  2018  Proceedings of the IEEE Wireless Communication...    Conference
# 21  2018  Lecture Notes in Computer Science (including s...       Journal
# 22  2018  Proceedings of the 19th IEEE International Con...    Conference
# 23  2018                    IEEE Internet of Things Journal       Journal
# 24  2018                                        IEEE Access       Journal
# 25  2018  Proceedings of the International Conference on...    Conference
# 26  2018    IEEE International Conference on Communications    Conference
# 27  2018  Proceedings of ACM Symposium on Access Control...    Conference
# 28  2018  Proceedings of the 3rd ACM Workshop on Attribu...      Workshop
# 29  2018  Proceedings of the 9th IFIP International Conf...    Conference
# ..   ...                                                ...           ...
# 60  2018                              Sensors (Switzerland)       Journal
# 61  2018                    IEEE Internet of Things Journal       Journal
# 62  2018                              Sensors (Switzerland)       Journal
# 63  2018                Security and Communication Networks       Journal
# 64  2018  Proceedings of the 11th IEEE International Con...    Conference
# 65  2018  Proceedings of the 2017 IEEE 17th Internationa...    Conference
# 66  2018                   Proceedings of the CEUR Workshop      Workshop
# 67  2018  Proceedings of the IEEE International Congress...    Conference
# 68  2018  Proceedings of the IEEE International Conferen...    Conference
# 69  2018  Procedings of the 11th IEEE International Conf...    Conference
# 70  2018                                        IEEE Access       Journal
# 71  2018                 Future Generation Computer Systems       Journal
# 72  2018                       IEEE Communications Magazine       Journal
# 73  2018  Proceedings of the IEEE World Forum on Interne...    Conference
# 74  2018  Proceedings of the Innovations in Intelligent ...    Conference
# 75  2018  Lecture Notes in Computer Science (including s...    Conference
# 76  2018  Proceedings of the IEEE International Conferen...    Conference
# 77  2018                                        IEEE Access       Journal
# 78  2018                                        IEEE Access       Journal
# 79  2018  Proceedings of the 8th International Conferenc...    Conference
# 80  2018  Proceedings of the International Conference on...    Conference
# 81  2018                       IEEE Communications Magazine       Journal
# 82  2018              Studies in Computational Intelligence  Book chapter
# 83  2018                    Journal of Systems Architecture       Journal
# 84  2018                    IEEE Internet of Things Journal       Journal
# 85  2018  Procedings of the IEEE International Symposium...    Conference
# 86  2018                      Frontiers of Computer Science       Journal
# 87  2018                    IEEE Internet of Things Journal       Journal
# 88  2018                                        IEEE Access       Journal
# 89  2018  Proceedings of the IEEE 27th International Con...    Conference
#
#    Number of Blockchains Data structure of ledger Global state in ledger  \
# 0                      1               blockchain                   UTXO
# 1                      1               blockchain                   UTXO
# 2                      1               blockchain                   UTXO
# 3                      1               Blockchain                 TX Log
# 4            more than 2               blockchain                account
# 5                      1               blockchain                   UTXO
# 6            more than 2               blockchain                   UTXO
# 7                      2               Blockchain                   UTXO
# 8                      1               blockchain                   UTXO
# 9                      1               blockchain                   UTXO
# 10                     1               blockchain                 TX Log
# 11                     1               blockchain                   UTXO
# 12                     1               blockchain                account
# 13                     1               blockchain                   UTXO
# 14                     1               blockchain                account
# 15                     1               blockchain                   UTXO
# 16                     1               blockchain                account
# 17                     1               blockchain                   UTXO
# 18                     1               blockchain                account
# 19                     1               blockchain                 TX Log
# 20                     1               blockchain                account
# 21                     1               blockchain                account
# 22                     1               blockchain                account
# 23                     2               blockchain                 TX Log
# 24                     1               blockchain                account
# 25                     1               blockchain                account
# 26                     1               blockchain                   UTXO
# 27                     2               blockchain                   UTXO
# 28                     1               blockchain                account
# 29                     1               blockchain                account
# ..                   ...                      ...                    ...
# 60                     1               blockchain                   UTXO
# 61                     1               blockchain                   UTXO
# 62                     1               blockchain                   UTXO
# 63           More than 2               blockchain                   UTXO
# 64                     1               blockchain                   UTXO
# 65                     1               blockchain                account
# 66                     1               blockchain                 TX Log
# 67                     1               blockchain                 TX Log
# 68                     1               blockchain                   UTXO
# 69                     1               blockchain                account
# 70                     2               blockchain         account & UTXO
# 71                     1               blockchain                account
# 72                     1               blockchain                   UTXO
# 73                     1               blockchain                account
# 74                     1               blockchain                account
# 75                     1               blockchain                account
# 76                     1               blockchain                account
# 77           More than 2               blockchain                   UTXO
# 78                     1               blockchain                   UTXO
# 79                     1               blockchain                 TX Log
# 80                     1               blockchain                account
# 81                     1               blockchain                account
# 82                     1               blockchain                account
# 83                     1               blockchain                 TX Log
# 84                     1               blockchain                   UTXO
# 85                     1               blockchain                   UTXO
# 86                     1               blockchain                account
# 87                     1               blockchain                account
# 88                     1               blockchain                account
# 89                     1               blockchain                account
#
#    Smart contract type                       Consensus scheme  \
# 0            Installed                  Proof-of-work Variant
# 1                  NaN                  Proof-of-work Variant
# 2                  NaN                  Proof-of-work Variant
# 3            installed                                   PBFT
# 4             on-chain  Proof-of-work Variant; Proof-of-stake
# 5                  NaN                  Proof-of-work Variant
# 6                  NaN                  Proof-of-work Variant
# 7                  NaN                                   None
# 8                  NaN                  Proof-of-work Variant
# 9                  NaN                  Proof-of-work Variant
# 10           Installed                                   PBFT
# 11                 NaN                  Proof-of-work Variant
# 12                 NaN                  Proof-of-work Variant
# 13                 NaN                  Proof-of-work Variant
# 14            on-chain                  Proof-of-work Variant
# 15                 NaN                  Proof-of-work Variant
# 16                 NaN                  Proof-of-work Variant
# 17                 NaN                  Proof-of-work Variant
# 18            on-chain                  Proof-of-work Variant
# 19           installed                                   PBFT
# 20            on-chain                  Proof-of-work Variant
# 21            on-chain                  Proof-of-work Variant
# 22            on-chain                  Proof-of-work Variant
# 23           installed                                   PBFT
# 24            on-chain                  Proof-of-work Variant
# 25            on-chain                  Proof-of-work Variant
# 26                 NaN                  Proof-of-work Variant
# 27                 NaN                  Proof-of-work Variant
# 28            on-chain                  Proof-of-work Variant
# 29            on-chain                  Proof-of-work Variant
# ..                 ...                                    ...
# 60                 NaN                  Proof-of-work Variant
# 61                 NaN                                   PBFT
# 62                 NaN                  Proof-of-work Variant
# 63                 NaN                  Proof-of-work Variant
# 64                 NaN                  Proof-of-work Variant
# 65            on-chain                  Proof-of-work Variant
# 66           installed                                    YAC
# 67           Installed                                   PBFT
# 68                 NaN                  Proof-of-work Variant
# 69            on-chain                  Proof-of-work Variant
# 70            on-chain                 PoW+PoS; proof-of-rule
# 71                 NaN                  Proof-of-work Variant
# 72                 NaN                          Proof-of-rule
# 73            on-chain                  Proof-of-work Variant
# 74            on-chain                  Proof-of-work Variant
# 75            on-chain                  Proof-of-work Variant
# 76            on-chain                  Proof-of-work Variant
# 77                 NaN                  Proof-of-work Variant
# 78                 NaN                  Proof-of-work Variant
# 79           Installed                                   PBFT
# 80            on-chain                         Proof-of-stake
# 81                 NaN                  Proof-of-work Variant
# 82            on-chain                  Proof-of-work Variant
# 83           Installed                                   PBFT
# 84                 NaN                                PoW+PoS
# 85                 NaN                  Proof-of-work Variant
# 86            on-chain                  Proof-of-work Variant
# 87            on-chain                  Proof-of-work Variant
# 88            on-chain                  Proof-of-work Variant
# 89                 NaN                  Proof-of-work Variant
#
#    Blockchain Permission Type Key Management Mechanism Development Technology  \
# 0                      Public                      NaN                Bitcoin
# 1                      Public                      NaN                Bitcoin
# 2                     Private                      NaN             MultiChain
# 3                  Consortium                      NaN     Hyperledger Fabric
# 4         Consortium; Private                      NaN        Monax; Ethereum
# 5                     Private                      NaN             MultiChain
# 6                      Public                      NaN                Bitcoin
# 7             Public; Private                      NaN     In-house BC system
# 8                      Public                      NaN                Bitcoin
# 9                      Public                      NaN     In-house BC system
# 10                 Consortium                      NaN     Hyperledger Fabric
# 11                     Public                      NaN     In-house BC system
# 12                     Public                      NaN               Ethereum
# 13                     public                      NaN                Bitcoin
# 14                     Public                      NaN               Ethereum
# 15                     Public                      NaN     In-house BC system
# 16                     Public                      NaN               Ethereum
# 17                     Public                      NaN                Bitcoin
# 18                    Private                      NaN               Ethereum
# 19                    Private                 local CA     Hyperledger Fabric
# 20                     Public                      NaN               Ethereum
# 21                     Public                      NaN               Ethereum
# 22                     Public                      NaN               Ethereum
# 23                    Private                 local CA     Hyperledger Fabric
# 24                     Public                      NaN               Ethereum
# 25                     public                      NaN               Ethereum
# 26                     Public                      NaN     In-house BC system
# 27                     public                      NaN     In-house BC system
# 28                     Public                      NaN               Ethereum
# 29                     Public                      NaN               Ethereum
# ..                        ...                      ...                    ...
# 60                     Public                      NaN     In-house BC system
# 61                 Consortium                      NaN     In-house BC system
# 62                     Public                      NaN     In-house BC system
# 63                     Public                      NaN     In-house BC system
# 64                     Public                      NaN     In-house BC system
# 65                     Public                      NaN               Ethereum
# 66                 Consortium                      NaN      Hyperledger Iroha
# 67                 Consortium                      NaN     Hyperledger Fabric
# 68                     Public                      NaN     In-house BC system
# 69                    Private                      NaN               Ethereum
# 70                     Public                      NaN     In-house BC system
# 71                     Public                      NaN               Ethereum
# 72                     Public                      NaN     In-house BC system
# 73                     Public                      NaN               Ethereum
# 74                     public                      NaN               Ethereum
# 75                    private                      NaN               Ethereum
# 76                     public                      NaN               Ethereum
# 77                     Public                      NaN     In-house BC system
# 78                     Public                      NaN     In-house BC system
# 79                 Consortium                      NaN     Hyperledger Fabric
# 80                    Private                      NaN                   Eris
# 81                     public                      NaN               Ethereum
# 82                     Public                      NaN     In-house BC system
# 83                 Consortium                      NaN     Hyperledger Fabric
# 84                     Public                      NaN     in-house BC system
# 85                     Public                      NaN     In-house BC system
# 86                     public                      NaN               Ethereum
# 87                     Public                      NaN               Ethereum
# 88                     Public                      NaN               Ethereum
# 89                     Public                      NaN               Ethereum
#
#                                               Pattern
# 0   blockchain -- UTXO -- Installed -- Proof-of-wo...
# 1   blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 2   blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 3   Blockchain -- TX Log -- installed -- PBFT -- C...
# 4   blockchain -- account -- on-chain -- Proof-of-...
# 5   blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 6   blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 7   Blockchain -- UTXO -- N/A -- None -- Public; P...
# 8   blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 9   blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 10  blockchain -- TX Log -- Installed -- PBFT -- C...
# 11  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 12  blockchain -- account -- N/A -- Proof-of-work ...
# 13  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 14  blockchain -- account -- on-chain -- Proof-of-...
# 15  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 16  blockchain -- account -- N/A -- Proof-of-work ...
# 17  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 18  blockchain -- account -- on-chain -- Proof-of-...
# 19  blockchain -- TX Log -- installed -- PBFT -- P...
# 20  blockchain -- account -- on-chain -- Proof-of-...
# 21  blockchain -- account -- on-chain -- Proof-of-...
# 22  blockchain -- account -- on-chain -- Proof-of-...
# 23  blockchain -- TX Log -- installed -- PBFT -- P...
# 24  blockchain -- account -- on-chain -- Proof-of-...
# 25  blockchain -- account -- on-chain -- Proof-of-...
# 26  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 27  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 28  blockchain -- account -- on-chain -- Proof-of-...
# 29  blockchain -- account -- on-chain -- Proof-of-...
# ..                                                ...
# 60  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 61    blockchain -- UTXO -- N/A -- PBFT -- Consortium
# 62  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 63  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 64  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 65  blockchain -- account -- on-chain -- Proof-of-...
# 66  blockchain -- TX Log -- installed -- YAC -- Co...
# 67  blockchain -- TX Log -- Installed -- PBFT -- C...
# 68  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 69  blockchain -- account -- on-chain -- Proof-of-...
# 70  blockchain -- account & UTXO -- on-chain -- Po...
# 71  blockchain -- account -- N/A -- Proof-of-work ...
# 72  blockchain -- UTXO -- N/A -- Proof-of-rule -- ...
# 73  blockchain -- account -- on-chain -- Proof-of-...
# 74  blockchain -- account -- on-chain -- Proof-of-...
# 75  blockchain -- account -- on-chain -- Proof-of-...
# 76  blockchain -- account -- on-chain -- Proof-of-...
# 77  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 78  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 79  blockchain -- TX Log -- Installed -- PBFT -- C...
# 80  blockchain -- account -- on-chain -- Proof-of-...
# 81  blockchain -- account -- N/A -- Proof-of-work ...
# 82  blockchain -- account -- on-chain -- Proof-of-...
# 83  blockchain -- TX Log -- Installed -- PBFT -- C...
# 84     blockchain -- UTXO -- N/A -- PoW+PoS -- Public
# 85  blockchain -- UTXO -- N/A -- Proof-of-work Var...
# 86  blockchain -- account -- on-chain -- Proof-of-...
# 87  blockchain -- account -- on-chain -- Proof-of-...
# 88  blockchain -- account -- on-chain -- Proof-of-...
# 89  blockchain -- account -- N/A -- Proof-of-work ...
#
# [90 rows x 14 columns]

# %%
"""
Countplot of pattern
"""


def draw_countplot(data, column, size = (10, 8), font = 12, fig_name = "fig", limit = 5):
    counts = data[column].value_counts()
    counts_lim = counts.iloc[:limit]
    data_lim = data[data[column].isin(counts_lim.index)]
    sns.countplot(y = column, data = data, orient="v", palette="coolwarm", 
              order = counts)
    #print(counts_lim.index)
    
    ax1 = plt.gca()
    ax1.yaxis.label.set_visible(False)
    ax1.xaxis.label.set_visible(False)
    plt.rcParams.update({"font.size": font})
    fig = plt.gcf()
    fig.set_size_inches(*size)
    for i, v in enumerate(data[column].value_counts()):
        ax1.text(v, i, " "+str(v), color='0.75', va='center', fontweight='bold')
    plt.show()
    fig.savefig(fig_name + ".pdf", bbox_inches='tight')

paper_pattern_relation = create_relation_paper_RQ(raw_df, "Pattern", "Pattern", split_sub_areas = False)

#paper_pattern_relation

draw_countplot(paper_pattern_relation, "Pattern", size = (10,2.5), fig_name = "RQ2_pattern")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     394         Draw the figure using the renderer.
#     395         """
# --> 396         self.renderer = self.get_renderer(cleared=True)
#     397         # acquire a lock on the shared font cache
#     398         RendererAgg.lock.acquire()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     415
#     416         if need_new_renderer:
# --> 417             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     418             self._lastKey = key
#     419         elif cleared:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      85         self.width = width
#      86         self.height = height
# ---> 87         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      88         self._filter_renderers = []
#      89
#
# ValueError: Image size of 127154x174 pixels is too large. It must be less than 2^16 in each direction.

# %%
"""
Countplot of consensus scheme
"""


paper_on_chain_logic_relation = create_relation_paper_RQ(raw_df, "Consensus scheme", "Consensus scheme", split_sub_areas = False)

draw_countplot(paper_on_chain_logic_relation, "Consensus scheme", size = (10,5), fig_name = "RQ2_consensus_schemes")

# %%
"""
Countplot of permission type
"""


paper_on_chain_logic_relation = create_relation_paper_RQ(raw_df, "Blockchain Permission Type", "Blockchain Permission Type", split_sub_areas = False)

draw_countplot(paper_on_chain_logic_relation, "Blockchain Permission Type", size = (10,1.5))

# %%
"""
Countplot of development technology
"""


paper_on_chain_logic_relation = create_relation_paper_RQ(raw_df, "Development Technology", "Development Technology", split_sub_areas = False)

draw_countplot(paper_on_chain_logic_relation, "Development Technology", size = (10,4), fig_name = "RQ2_dev_tech")

# %%
"""
Loads the extracted data for RQ3 on optimisation problems and solutions
"""

raw_path = "RQ2_RQ3/extraction_Q2_Q3_v1.0.0.xlsx"

raw_df = pd.read_excel(raw_path, sheet_name="RQ3")
raw_df
# Out:
#                  Paper ID                                              Title  \
# 0            Zhang:2015:1  An IoT Electric Business Model Based on the Pr...
# 1            Ouaddah:2016  FairAccess: a new Blockchain-based access cont...
# 2        Samaniego:2016:1  Using blockchain to push software-defined IoT ...
# 3              Ali:2017:1  The quest for fully smart autonomous business ...
# 4              Ali:2017:2          IoT data privacy via blockchains and IPFS
# 5        Boudguiga:2017:1  Towards better availability and accountability...
# 6             Daza:2017:1  CONNECT: CONtextual NamE disCovery for blockch...
# 7            Dorri:2017:2            Towards an optimized blockchain for IoT
# 8             Kaga:2017:1  A secure and practical signature scheme for bl...
# 9              Lee:2017:1  Blockchain-based secure firmware update for em...
# 10              Li:2017:1  A blockchain based new secure multi-layer netw...
# 11           Liang:2017:1  Towards data assurance and resilience in IoT u...
# 12             Liu:2017:1  Blockchain Based Data Integrity Service Framew...
# 13       Lundqvist:2017:1  Thing-to-thing electricity micro payments usin...
# 14         Missier:2017:1  Mind My Value: A decentralized infrastructure ...
# 15         Shafagh:2017:1  Towards blockchain-based auditable storage and...
# 16             Xie:2017:1  Secured Data Storage Scheme Based on Block Cha...
# 17             Zhu:2017:1  Autonomic Identity Framework for the Internet ...
# 18        Afanasev:2018:1  A Design of Cyber-physical Production System P...
# 19         Agrawal:2018:1        Continuous Security in IoT Using Blockchain
# 20         Alphand:2018:1  IoTChain: A blockchain security architecture f...
# 21           Angin:2018:1  A blockchain-based decentralized security arch...
# 22          Ayoade:2018:1  Decentralized IoT data management using blockc...
# 23          Biswas:2018:1  A Scalable Blockchain Framework for Secure Tra...
# 24             Cha:2018:1  A Blockchain Connected Gateway for BLE-Based D...
# 25            Choi:2018:1       A Blockchain-based Secure IoT Control Scheme
# 26           Danzi:2018:1  Analysis of the communication traffic for bloc...
# 27        DiPietro:2018:1  A blockchain-based trust system for the intern...
# 28       Dukkipati:2018:1  Decentralized, blockchain based access control...
# 29           Ellul:2018:1  AlkylVM: A Virtual Machine for Smart Contract ...
# ..                    ...                                                ...
# 60              Qi:2018:1  QoS-driven adaptive trust service coordination...
# 61             Qiu:2018:1  Blockchain-Based Software-Defined Industrial I...
# 62              Qu:2018:1  A hypergraph-based blockchain model and applic...
# 63              Qu:2018:2  Blockchain based credibility verification meth...
# 64  Rahulamathavan:2018:1  Privacy-preserving blockchain based IoT ecosys...
# 65            Rifi:2018:1  Towards using blockchain technology for IoT da...
# 66            Ruta:2018:1  A Blockchain Infrastructure for the Semantic W...
# 67       Samaniego:2018:1          Zero-Trust Hierarchical Management in IoT
# 68     Sanseverino:2018:1  The blockchain in microgrids for transacting e...
# 69       Saravanan:2018:1  SMEAD: A secured mobile enabled assisting devi...
# 70          Sharma:2018:1  A Software Defined Fog Node Based Distributed ...
# 71          Sharma:2018:2  Blockchain based hybrid network architecture f...
# 72          Sharma:2018:3  Energy-Efficient Distributed Network Architect...
# 73           Singh:2018:1  Trust Bit: Reward-based intelligent vehicle co...
# 74      Spathoulas:2018:1  Towards Reliable Integrity in Blacklisting: Fa...
# 75             Sun:2018:1  Using ethereum blockchain in Internet of Thing...
# 76           Tapas:2018:1  Blockchain-Based IoT-cloud authorization and d...
# 77           Uddin:2018:1  Continuous Patient Monitoring with a Patient C...
# 78            Wang:2018:1  A Blockchain Based Privacy-Preserving Incentiv...
# 79             Wen:2018:1  Evidence and trust: IoT Collaborative security...
# 80              Wu:2018:1  An Out-of-band Authentication Scheme for Inter...
# 81           Xiong:2018:1        When mobile blockchain meets edge computing
# 82              Xu:2018:1  A blockchain-based storage system for data ana...
# 83            Yang:2018:1  Smart-toy-edge-computing-oriented data exchang...
# 84            Yang:2018:2  Blockchain-based Decentralized Trust Managemen...
# 85            Yang:2018:3  A blockchain-based reputation system for data ...
# 86           Zhang:2018:1  SMER: a secure method of exchanging resources ...
# 87           Zhang:2018:2  Smart Contract-Based Access Control for the In...
# 88            Zhou:2018:1  BeeKeeper: A Blockchain-Based IoT System with ...
# 89          Zouari:2018:1  Privacy Preserving Profile Matching Protocol f...
#
#     Year                                              Venue          Type  \
# 0   2015                                          ICIN 2015    Conference
# 1   2016                Security and Communication Networks       Journal
# 2   2016     ACM International Conference Proceeding Series    Conference
# 3   2017     ACM International Conference Proceeding Series    Conference
# 4   2017     ACM International Conference Proceeding Series    Conference
# 5   2017  Proceedings of the 2nd IEEE European Symposium...      Workshop
# 6   2017  Proceedings of IEEE International Conference o...    Conference
# 7   2017  Proceedings of the 2nd International Conferenc...    Conference
# 8   2017  Lecture Notes in Computer Science (including s...       Journal
# 9   2017                          Journal of Supercomputing       Journal
# 10  2017  Proceedings of the 2nd IEEE International Cong...    Conference
# 11  2017  Proceedings of IEEE Military Communications Co...    Conference
# 12  2017  Proceedings of the IEEE 24th International Con...    Conference
# 13  2017  Proceedings of the Global Internet of Things S...    Conference
# 14  2017     ACM International Conference Proceeding Series    Conference
# 15  2017  Proceedings of the 2017 Cloud Computing Securi...      Workshop
# 16  2017  Proceedings of the 3rd International Conferenc...    Conference
# 17  2017  Proceedings of the IEEE International Conferen...    Conference
# 18  2018  Proceedings of the 22nd Conference of Open Inn...    Conference
# 19  2018  Proceedings of the IEEE International Conferen...    Conference
# 20  2018  Proceedings of the IEEE Wireless Communication...    Conference
# 21  2018  Lecture Notes in Computer Science (including s...       Journal
# 22  2018  Proceedings of the 19th IEEE International Con...    Conference
# 23  2018                    IEEE Internet of Things Journal       Journal
# 24  2018                                        IEEE Access       Journal
# 25  2018  Proceedings of the International Conference on...    Conference
# 26  2018    IEEE International Conference on Communications    Conference
# 27  2018  Proceedings of ACM Symposium on Access Control...    Conference
# 28  2018  Proceedings of the 3rd ACM Workshop on Attribu...      Workshop
# 29  2018  Proceedings of the 9th IFIP International Conf...    Conference
# ..   ...                                                ...           ...
# 60  2018                              Sensors (Switzerland)       Journal
# 61  2018                    IEEE Internet of Things Journal       Journal
# 62  2018                              Sensors (Switzerland)       Journal
# 63  2018                Security and Communication Networks       Journal
# 64  2018  Proceedings of the 11th IEEE International Con...    Conference
# 65  2018  Proceedings of the 2017 IEEE 17th Internationa...    Conference
# 66  2018                   Proceedings of the CEUR Workshop      Workshop
# 67  2018  Proceedings of the IEEE International Congress...    Conference
# 68  2018  Proceedings of the IEEE International Conferen...    Conference
# 69  2018  Procedings of the 11th IEEE International Conf...    Conference
# 70  2018                                        IEEE Access       Journal
# 71  2018                 Future Generation Computer Systems       Journal
# 72  2018                       IEEE Communications Magazine       Journal
# 73  2018  Proceedings of the IEEE World Forum on Interne...    Conference
# 74  2018  Proceedings of the Innovations in Intelligent ...    Conference
# 75  2018  Lecture Notes in Computer Science (including s...    Conference
# 76  2018  Proceedings of the IEEE International Conferen...    Conference
# 77  2018                                        IEEE Access       Journal
# 78  2018                                        IEEE Access       Journal
# 79  2018  Proceedings of the 8th International Conferenc...    Conference
# 80  2018  Proceedings of the International Conference on...    Conference
# 81  2018                       IEEE Communications Magazine       Journal
# 82  2018              Studies in Computational Intelligence  Book chapter
# 83  2018                    Journal of Systems Architecture       Journal
# 84  2018                    IEEE Internet of Things Journal       Journal
# 85  2018  Procedings of the IEEE International Symposium...    Conference
# 86  2018                      Frontiers of Computer Science       Journal
# 87  2018                    IEEE Internet of Things Journal       Journal
# 88  2018                                        IEEE Access       Journal
# 89  2018  Proceedings of the IEEE 27th International Con...    Conference
#
#                                               Problem  \
# 0                                       Not addressed
# 1                                       Not addressed
# 2                                       Not addressed
# 3                                       Not addressed
# 4   IoT devices form different groups that belong ...
# 5                                       Not addressed
# 6                                       Not addressed
# 7   IoT injects too many transactions at too high ...
# 8   Devices might generate transactions without ow...
# 9                                       Not addressed
# 10                                      Not addressed
# 11                                      Not addressed
# 12                                      Not addressed
# 13  IoT injects too many transactions at too high ...
# 14                                      Not addressed
# 15                                      Not addressed
# 16  IoT injects too many transactions at too high ...
# 17                                      Not addressed
# 18                                      Not addressed
# 19                                      Not addressed
# 20                                      Not addressed
# 21                                      Not addressed
# 22                                      Not addressed
# 23  IoT injects too many transactions at too high ...
# 24                                      Not addressed
# 25                                      Not addressed
# 26                                      Not addressed
# 27                                      Not addressed
# 28                                      Not addressed
# 29  IoT devices lack resources to maintain blockch...
# ..                                                ...
# 60                                      Not addressed
# 61                                      Not addressed
# 62                          Reduce the size of ledger
# 63        IoT devices lack resources to generate keys
# 64                                      Not addressed
# 65                                      Not addressed
# 66                                      Not addressed
# 67                     Enable zero-trust model in IoT
# 68                                      Not addressed
# 69                                      Not addressed
# 70  Exchange of services requires off-chain valida...
# 71                                      Not addressed
# 72                                      Not addressed
# 73                                      Not addressed
# 74                                      Not addressed
# 75  IoT devices lack resources to maintain blockch...
# 76                                      Not addressed
# 77  Blockchain PoW consumes too much energy for Io...
# 78                                      Not addressed
# 79                                      Not addressed
# 80                                      Not addressed
# 81                                      Not addressed
# 82                                      Not addressed
# 83                                      Not addressed
# 84                                      Not addressed
# 85                                      Not addressed
# 86                                      Not addressed
# 87                                      Not addressed
# 88  IoT devices lack resources to maintain blockch...
# 89                                      Not addressed
#
#                                              Solution
# 0                                       Not addressed
# 1                                       Not addressed
# 2                                       Not addressed
# 3                                       Not addressed
# 4      Integrate side-chains with a consortium chain.
# 5                                       Not addressed
# 6                                       Not addressed
# 7                  Replace PoW with distributed trust
# 8   Integrate owners’ biometrics into the signatur...
# 9                                       Not addressed
# 10                                      Not addressed
# 11                                      Not addressed
# 12                                      Not addressed
# 13         Aggregate data before writing to the chain
# 14                                      Not addressed
# 15                                      Not addressed
# 16            Filter data before writing to the chain
# 17                                      Not addressed
# 18                                      Not addressed
# 19                                      Not addressed
# 20                                      Not addressed
# 21                                      Not addressed
# 22                                      Not addressed
# 23                          Create a local side chain
# 24                                      Not addressed
# 25                                      Not addressed
# 26                                      Not addressed
# 27                                      Not addressed
# 28                                      Not addressed
# 29                 Split-virtual machine architecture
# ..                                                ...
# 60                                      Not addressed
# 61                                      Not addressed
# 62  Partition the blockchain network using hypergr...
# 63              Miners generate key pairs for devices
# 64                                      Not addressed
# 65                                      Not addressed
# 66                                      Not addressed
# 67                                Hierarchical mining
# 68                                      Not addressed
# 69                                      Not addressed
# 70                 Proof-of-service; 2-hop blockchain
# 71                                      Not addressed
# 72                                      Not addressed
# 73                                      Not addressed
# 74                                      Not addressed
# 75               Run lightweight nodes on IoT devices
# 76                                      Not addressed
# 77                            Selective Proof-of-work
# 78                                      Not addressed
# 79                                      Not addressed
# 80                                      Not addressed
# 81                                      Not addressed
# 82                                      Not addressed
# 83                                      Not addressed
# 84                                      Not addressed
# 85                                      Not addressed
# 86                                      Not addressed
# 87                                      Not addressed
# 88               Run lightweight nodes on IoT devices
# 89                                      Not addressed
#
# [90 rows x 7 columns]

# %%
"""
Countplot of problem
"""


paper_on_chain_logic_relation = create_relation_paper_RQ(raw_df, "Problem", "Problem", split_sub_areas = False)

draw_countplot(paper_on_chain_logic_relation, "Problem", size = (8,6.5), fig_name = "RQ3_problems")

# %%
"""
Countplot of solution
"""


paper_on_chain_logic_relation = create_relation_paper_RQ(raw_df, "Solution", "Solution", split_sub_areas = False)

draw_countplot(paper_on_chain_logic_relation, "Solution", size = (10,11), fig_name = "RQ3_solutions")
