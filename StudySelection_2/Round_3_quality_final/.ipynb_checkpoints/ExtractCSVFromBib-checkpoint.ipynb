# %%
import bibtexparser
import pandas as pd

# %%
with open('Scopus_01052019_01012020_final.txt') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

# %%
bib_database.entries
# Out:
# [{'type': 'Conference Proceedings',
#   'doi': '10.1109/SMARTCOMP.2019.00049',
#   'booktitle': '"Proceedings - 2019 IEEE International Conference on Smart Computing, SMARTCOMP 2019"',
#   'title': 'BRUSCHETTA: An IoT blockchain-based framework for certifying extra virgin olive oil supply chain',
#   'author': 'A., Arena and A., Bianchini and P., Perazzo and C., Vallati and G., Dini',
#   'ENTRYTYPE': 'inproceedings',
#   'ID': 'Arena:2019:1'},
#  {'type': 'Conference Proceedings',
#   'doi': '10.1109/ICIOT.2019.00034',
#   'booktitle': '"Proceedings - 2019 IEEE International Congress on Internet of Things, ICIOT 2019 - Part of the 2019 IEEE World Congress on Services"',
#   'title': 'Advancements towards Global IoT device discovery and integration',
#   'author': 'A., Dawod and D., Georgakopoulos and P.P., Jayaraman and A., Nirmalathas',
#   'ENTRYTYPE': 'inproceedings',
#   'ID': 'Dawod:2019:1'},
#  {'type': 'Journal Article',
#   'year': '2019',
# ...
