# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
"""
Loads the extracted data
"""

raw_path = "extraction_Q1_45_23-11.xlsx"
raw_df = pd.read_excel(raw_path)
raw_df
# Out:
#             Paper ID                                              Title  Year  \
# 0       Zhang:2015:1  An IoT Electric Business Model Based on the Pr...  2015
# 1       Ouaddah:2016  FairAccess: a new Blockchain-based access cont...  2016
# 2   Samaniego:2016:1  Using blockchain to push software-defined IoT ...  2016
# 3         Ali:2017:1  The quest for fully smart autonomous business ...  2017
# 4         Ali:2017:2          IoT data privacy via blockchains and IPFS  2017
# 5   Boudguiga:2017:1  Towards better availability and accountability...  2017
# 6        Daza:2017:1  CONNECT: CONtextual NamE disCovery for blockch...  2017
# 7       Dorri:2017:2            Towards an optimized blockchain for IoT  2017
# 8        Kaga:2017:1  A secure and practical signature scheme for bl...  2017
# 9         Lee:2017:1  Blockchain-based secure firmware update for em...  2017
# 10         Li:2017:1  A blockchain based new secure multi-layer netw...  2017
# 11      Liang:2017:1  Towards data assurance and resilience in IoT u...  2017
# 12        Liu:2017:1  Blockchain Based Data Integrity Service Framew...  2017
# 13  Lundqvist:2017:1  Thing-to-thing electricity micro payments usin...  2017
# 14    Missier:2017:1  Mind My Value: A decentralized infrastructure ...  2017
# 15    Shafagh:2017:1  Towards blockchain-based auditable storage and...  2017
# 16        Xie:2017:1  Secured Data Storage Scheme Based on Block Cha...  2017
# 17        Zhu:2017:1  Autonomic Identity Framework for the Internet ...  2017
# 18   Afanasev:2018:1  A Design of Cyber-physical Production System P...  2018
# 19    Agrawal:2018:1        Continuous Security in IoT Using Blockchain  2018
# 20    Alphand:2018:1  IoTChain: A blockchain security architecture f...  2018
# 21      Angin:2018:1  A blockchain-based decentralized security arch...  2018
# 22     Ayoade:2018:1  Decentralized IoT data management using blockc...  2018
# 23     Biswas:2018:1  A Scalable Blockchain Framework for Secure Tra...  2018
# 24        Cha:2018:1  A Blockchain Connected Gateway for BLE-Based D...  2018
# 25       Choi:2018:1       A Blockchain-based Secure IoT Control Scheme  2018
# 26      Danzi:2018:1  Analysis of the communication traffic for bloc...  2018
# 27   DiPietro:2018:1  A blockchain-based trust system for the intern...  2018
# 28  Dukkipati:2018:1  Decentralized, blockchain based access control...  2018
# 29      Ellul:2018:1  AlkylVM: A Virtual Machine for Smart Contract ...  2018
# 30        Fan:2018:1  Faster dual-key stealth address for blockchain...  2018
# 31        Fan:2018:2  Blockchain-based Secure Time Protection Scheme...  2018
# 32      Ferro:2018:1  Technical development of a security platform f...  2018
# 33      Gallo:2018:1  BlockSee: Blockchain for IoT Video Surveillanc...  2018
# 34      Hammi:2018:1  BCTrust: A decentralized authentication blockc...  2018
# 35      Hammi:2018:2  Bubbles of Trust: A decentralized blockchain-b...  2018
# 36      Hasan:2018:1  Chained of Things: A Secure and Dependable Des...  2018
# 37    Hossain:2018:1  FIF-IoT: A Forensic Investigation Framework fo...  2018
# 38      Huang:2018:1  A decentralized solution for IoT data trusted ...  2018
# 39     Javaid:2018:1  Mitigating IoT device based DDoS attacks using...  2018
# 40        Kak:2018:1           Privacy Improvement Architecture for IoT  2018
# 41      Kalam:2018:1  Emergence-Based Access Control: New Approach t...  2018
# 42       Kang:2018:1  A Blockchain-Based Energy Trading Platform for...  2018
# 43       Kang:2018:2  Blockchain for Secure and Efficient Data Shari...  2018
#
#                                                 Venue        Type  \
# 0                                           ICIN 2015  Conference
# 1                 Security and Communication Networks     Journal
# 2      ACM International Conference Proceeding Series  Conference
# 3      ACM International Conference Proceeding Series  Conference
# 4      ACM International Conference Proceeding Series  Conference
# 5   Proceedings of the 2nd IEEE European Symposium...    Workshop
# 6   Proceedings of IEEE International Conference o...  Conference
# 7   Proceedings of the 2nd International Conferenc...  Conference
# 8   Lecture Notes in Computer Science (including s...     Journal
# 9                           Journal of Supercomputing     Journal
# 10  Proceedings of the 2nd IEEE International Cong...  Conference
# 11  Proceedings of IEEE Military Communications Co...  Conference
# 12  Proceedings of the IEEE 24th International Con...  Conference
# 13  Proceedings of the Global Internet of Things S...  Conference
# 14     ACM International Conference Proceeding Series  Conference
# 15  Proceedings of the 2017 Cloud Computing Securi...    Workshop
# 16  Proceedings of the 3rd International Conferenc...  Conference
# 17  Proceedings of the IEEE International Conferen...  Conference
# 18  Proceedings of the 22nd Conference of Open Inn...  Conference
# 19  Proceedings of the IEEE International Conferen...  Conference
# 20  Proceedings of the IEEE Wireless Communication...  Conference
# 21  Lecture Notes in Computer Science (including s...     Journal
# 22  Proceedings of the 19th IEEE International Con...  Conference
# 23                    IEEE Internet of Things Journal     Journal
# 24                                        IEEE Access     Journal
# 25  Proceedings of the International Conference on...  Conference
# 26    IEEE International Conference on Communications  Conference
# 27  Proceedings of ACM Symposium on Access Control...  Conference
# 28  Proceedings of the 3rd ACM Workshop on Attribu...    Workshop
# 29  Proceedings of the 9th IFIP International Conf...  Conference
# 30  Lecture Notes in Computer Science (including s...     Journal
# 31                    IEEE Internet of Things Journal     Journal
# 32  Communications in Computer and Information Sci...     Journal
# 33  Proceedings of the IEEE International Conferen...  Conference
# 34  Proceedings of IEEE Wireless Communications an...  Conference
# 35                             Computers and Security     Journal
# 36  Proceedings of the IEEE 42nd Annual Computer S...  Conference
# 37  Proceedings of the IEEE International Congress...  Conference
# 38  Proceedings of the 3rd IEEE International Conf...  Conference
# 39  Proceedings of the 1st Workshop on Cryptocurre...    Workshop
# 40  Proceedings of IEEE International Congress on ...  Conference
# 41  Proceedings of the 1st International Conferenc...  Conference
# 42  Proceedings of the 3rd International Conferenc...  Conference
# 43                    IEEE Internet of Things Journal     Journal
#
#                                     RQ1: Problem Area  \
# 0            Enabling the exchange of IoT commodities
# 1   Security: confidentiality, integrity, authenti...
# 2                         Performance: Time behaviour
# 3   Security: confidentiality, integrity, authenti...
# 4   Security: non-repudiation, accountability; Ena...
# 5   Reliability: Availability; Security: Integrity...
# 6   Enabling applications to discover IoT services...
# 7   Security: confidentiality, integrity, authenti...
# 8                              Security: authenticity
# 9   Reliability: Availability; Security: Integrity...
# 10  Reliability: Availability; Performance: Time b...
# 11  Security: integrity, authenticity, accountability
# 12                                Security: integrity
# 13           Enabling the exchange of IoT commodities
# 14           Enabling the exchange of IoT commodities
# 15  Security: accountability; Enabling the private...
# 16                Security: integrity, accountability
# 17                             Security: authenticity
# 18                Security: integrity, accountability
# 19  Security: integrity, non-repudiation, authenti...
# 20                             Security: authenticity
# 21                Security: integrity, accountability
# 22  Security: confidentiality, authenticity, accou...
# 23  Security: integrity, non-repudiation, authenti...
# 24               Security: confidentiality, integrity
# 25  Reliability: Availability; Security: Integrity...
# 26           Enabling the exchange of IoT commodities
# 27                    Compatibility: interoperability
# 28               Security: confidentiality, integrity
# 29  Automate physical processes; Security: Integri...
# 30  Security: confidentiality, integrity, authenti...
# 31  Enabling time synchronisation among IoT device...
# 32                  Security: integrity, authenticity
# 33                                Security: integrity
# 34                             Security: authenticity
# 35                             Security: authenticity
# 36  Enabling the exchange of IoT commodities; Auto...
# 37  Record interactions among IoT devices and serv...
# 38  Enabling the exchange of IoT commodities; Secu...
# 39                                Security: integrity
# 40  Record interactions among IoT devices and serv...
# 41               Security: confidentiality, integrity
# 42           Enabling the exchange of IoT commodities
# 43  Security: confidentiality, integrity, authenti...
#
#                                  RQ1: Technical Issue  RQ2: Replace or add  \
# 0                         Remove trusted intermediary                  NaN
# 1           Provide privacy-preserving access control                  NaN
# 2            Control the distribution of IoT services                  NaN
# 3   Provide cross IoT platform identity management...                  NaN
# 4                         Remove trusted intermediary                  NaN
# 5              Distribute software patches to devices                  NaN
# 6   Remove trusted intermediary; Allow identifying...                  NaN
# 7   Remove trusted intermediary; Protecting user p...                  NaN
# 8   Ensuring that the user of a private key is its...                  NaN
# 9              Distribute software patches to devices                  NaN
# 10                        Remove trusted intermediary                  NaN
# 11  Build a trusted environment for device to back...                  NaN
# 12                        Remove trusted intermediary                  NaN
# 13                Handling volumous automatic payment                  NaN
# 14                        Remove trusted intermediary                  NaN
# 15                        Remove trusted intermediary                  NaN
# 16              Prevent data tampering by human users                  NaN
# 17  Generate digital signature of devices; Associa...                  NaN
# 18  Build a trusted environment for device to back...                  NaN
# 19  Provide continuous security; maintain trail of...                  NaN
# 20                        Remove trusted intermediary                  NaN
# 21                        Remove trusted intermediary                  NaN
# 22                        Remove trusted intermediary                  NaN
# 23  Build a trusted environment for transactions b...                  NaN
# 24  Remove trusted intermediary; manage privacy pr...                  NaN
# 25  Remove trusted intermediary; Control IoT devic...                  NaN
# 26                        Remove trusted intermediary                  NaN
# 27           Allow secure domains to trust each other                  NaN
# 28  Remove trusted intermediary; Provide privacy-p...                  NaN
# 29  Enable verifiable and enforceable automatic pr...                  NaN
# 30                        Remove trusted intermediary                  NaN
# 31  Remove trusted intermediary; Verify the announ...                  NaN
# 32                        Remove trusted intermediary                  NaN
# 33                        Remove trusted intermediary                  NaN
# 34                        Remove trusted intermediary                  NaN
# 35                        Remove trusted intermediary                  NaN
# 36                        Remove trusted intermediary                  NaN
# 37                        Remove trusted intermediary                  NaN
# 38                        Remove trusted intermediary                  NaN
# 39  Prevent devices from participating in DDoS att...                  NaN
# 40                 Record both requests and responses                  NaN
# 41          Provide privacy-preserving access control                  NaN
# 42  Enable verifiable and enforceable automatic pr...                  NaN
# 43  Enable verifiable and enforceable automatic pr...                  NaN
#
#     RQ2: Affected component  RQ2: Utlized BC character  RQ2: Ledger location  \
# 0                       NaN                        NaN                   NaN
# 1                       NaN                        NaN                   NaN
# 2                       NaN                        NaN                   NaN
# 3                       NaN                        NaN                   NaN
# 4                       NaN                        NaN                   NaN
# 5                       NaN                        NaN                   NaN
# 6                       NaN                        NaN                   NaN
# 7                       NaN                        NaN                   NaN
# 8                       NaN                        NaN                   NaN
# 9                       NaN                        NaN                   NaN
# 10                      NaN                        NaN                   NaN
# 11                      NaN                        NaN                   NaN
# 12                      NaN                        NaN                   NaN
# 13                      NaN                        NaN                   NaN
# 14                      NaN                        NaN                   NaN
# 15                      NaN                        NaN                   NaN
# 16                      NaN                        NaN                   NaN
# 17                      NaN                        NaN                   NaN
# 18                      NaN                        NaN                   NaN
# 19                      NaN                        NaN                   NaN
# 20                      NaN                        NaN                   NaN
# 21                      NaN                        NaN                   NaN
# 22                      NaN                        NaN                   NaN
# 23                      NaN                        NaN                   NaN
# 24                      NaN                        NaN                   NaN
# 25                      NaN                        NaN                   NaN
# 26                      NaN                        NaN                   NaN
# 27                      NaN                        NaN                   NaN
# 28                      NaN                        NaN                   NaN
# 29                      NaN                        NaN                   NaN
# 30                      NaN                        NaN                   NaN
# 31                      NaN                        NaN                   NaN
# 32                      NaN                        NaN                   NaN
# 33                      NaN                        NaN                   NaN
# 34                      NaN                        NaN                   NaN
# 35                      NaN                        NaN                   NaN
# 36                      NaN                        NaN                   NaN
# 37                      NaN                        NaN                   NaN
# 38                      NaN                        NaN                   NaN
# 39                      NaN                        NaN                   NaN
# 40                      NaN                        NaN                   NaN
# 41                      NaN                        NaN                   NaN
# 42                      NaN                        NaN                   NaN
# 43                      NaN                        NaN                   NaN
#
#     RQ2: Mining node selection scheme  RQ2: Consensus algorithm  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
# 5                                 NaN                       NaN
# 6                                 NaN                       NaN
# 7                                 NaN                       NaN
# 8                                 NaN                       NaN
# 9                                 NaN                       NaN
# 10                                NaN                       NaN
# 11                                NaN                       NaN
# 12                                NaN                       NaN
# 13                                NaN                       NaN
# 14                                NaN                       NaN
# 15                                NaN                       NaN
# 16                                NaN                       NaN
# 17                                NaN                       NaN
# 18                                NaN                       NaN
# 19                                NaN                       NaN
# 20                                NaN                       NaN
# 21                                NaN                       NaN
# 22                                NaN                       NaN
# 23                                NaN                       NaN
# 24                                NaN                       NaN
# 25                                NaN                       NaN
# 26                                NaN                       NaN
# 27                                NaN                       NaN
# 28                                NaN                       NaN
# 29                                NaN                       NaN
# 30                                NaN                       NaN
# 31                                NaN                       NaN
# 32                                NaN                       NaN
# 33                                NaN                       NaN
# 34                                NaN                       NaN
# 35                                NaN                       NaN
# 36                                NaN                       NaN
# 37                                NaN                       NaN
# 38                                NaN                       NaN
# 39                                NaN                       NaN
# 40                                NaN                       NaN
# 41                                NaN                       NaN
# 42                                NaN                       NaN
# 43                                NaN                       NaN
#
#     RQ3: Perceived challenge  RQ3: Carried out BC optimisation
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
# 5                        NaN                               NaN
# 6                        NaN                               NaN
# 7                        NaN                               NaN
# 8                        NaN                               NaN
# 9                        NaN                               NaN
# 10                       NaN                               NaN
# 11                       NaN                               NaN
# 12                       NaN                               NaN
# 13                       NaN                               NaN
# 14                       NaN                               NaN
# 15                       NaN                               NaN
# 16                       NaN                               NaN
# 17                       NaN                               NaN
# 18                       NaN                               NaN
# 19                       NaN                               NaN
# 20                       NaN                               NaN
# 21                       NaN                               NaN
# 22                       NaN                               NaN
# 23                       NaN                               NaN
# 24                       NaN                               NaN
# 25                       NaN                               NaN
# 26                       NaN                               NaN
# 27                       NaN                               NaN
# 28                       NaN                               NaN
# 29                       NaN                               NaN
# 30                       NaN                               NaN
# 31                       NaN                               NaN
# 32                       NaN                               NaN
# 33                       NaN                               NaN
# 34                       NaN                               NaN
# 35                       NaN                               NaN
# 36                       NaN                               NaN
# 37                       NaN                               NaN
# 38                       NaN                               NaN
# 39                       NaN                               NaN
# 40                       NaN                               NaN
# 41                       NaN                               NaN
# 42                       NaN                               NaN
# 43                       NaN                               NaN

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 15 columns):
# Paper ID                             44 non-null object
# Title                                44 non-null object
# Year                                 44 non-null int64
# Venue                                44 non-null object
# Type                                 44 non-null object
# RQ1: Problem Area                    44 non-null object
# RQ1: Technical Issue                 44 non-null object
# RQ2: Replace or add                  0 non-null float64
# RQ2: Affected component              0 non-null float64
# RQ2: Utlized BC character            0 non-null float64
# RQ2: Ledger location                 0 non-null float64
# RQ2: Mining node selection scheme    0 non-null float64
# RQ2: Consensus algorithm             0 non-null float64
# RQ3: Perceived challenge             0 non-null float64
# RQ3: Carried out BC optimisation     0 non-null float64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 5.2+ KB

# %%
"""
This method splits the strings in RQs into a list of items.

These items can be areas and subareas of research.
"""

def split_areas(input_data, lv1_sep = ";"):
    return input_data.split(lv1_sep)

def _split_sub_areas(input_data, lv2_sep = ",", area_sub_sep = ":"):
    split_result = input_data.split(lv2_sep)
    if len(split_result) == 1:
        return [input_data.strip()]
    else:
        sub_areas = []
        area_name = split_result[0].split(area_sub_sep)[0].strip()
        # The first item has the format area:subarea, while the rest does not have area.
        # Try to split the string by : and grab the second part.
        # If it is possible, then we are processing the first element.
        # If we have error, it means we are processing the rest of the elements.
        for sub in split_result:
            try:
                sub_areas.append("%s:%s" % (area_name, sub.split(area_sub_sep)[1].strip().lower()))
            except IndexError:
                sub_areas.append("%s:%s" % (area_name, sub.strip().lower()))
        return sub_areas
    
def split_sub_areas(input_data, lv2_sep = ",", area_sub_sep = ":"):
    split_result = input_data.split(lv2_sep)
    sub_areas = []
    
    # Set the area name only if we can find the colon
    area_name = ""
    if split_result[0].find(":") != -1:
        area_name = split_result[0].split(area_sub_sep)[0].strip()
        
    for sub in split_result:
        sub_area = ""
        
        # The first item has the format area:subarea, while the rest does not have area.
        # Try to split the string by : and grab the second part.
        # If it is possible, then we are processing the first element.
        # If we have error, it means we are processing the rest of the elements.
        try:
            sub_area = sub.split(area_sub_sep)[1].strip().lower()
            
        except IndexError:
            sub_area = sub.strip().lower()        
        # Return the sub_area as is if there is no area name
        if area_name == "":
            sub_areas.append(sub_area)
        else:
            sub_areas.append("%s:%s" % (area_name, sub_area))
        
    return sub_areas

def split_input_data(input_data, split_areas = split_areas, split_sub_areas = split_sub_areas):
    results = []
    areas = split_areas(input_data)
    for area in areas:
        results.extend(split_sub_areas(area))
    return results

test_string = "Security: non-repudiation, accountability; Enabling the private ownership of IoT commodities; Enabling the exchange of IoT commodities"
split_input_data(test_string)
# Out:
# ['Security:non-repudiation',
#  'Security:accountability',
#  'enabling the private ownership of iot commodities',
#  'enabling the exchange of iot commodities']

# %%
"""
Create relation between papers and values of an RQ
"""

def create_relation_paper_RQ(raw_df, rq_name_in_df, rq_display_name):
    # prepare an empty data frame
    paper_ids = []
    titles = []
    years = []
    venues = []
    types = []
    problem_areas = []
    data = {
        "Paper ID" : paper_ids,
        "Title" : titles,
        "Year" : years,
        "Venue" : venues,
        "Type" : types,
        rq_display_name : problem_areas
    }

    # apply text split
    rq_lists = raw_df[rq_name_in_df].apply(split_input_data)
    

    # construct the data frame
    for i in range(len(rq_lists)):
        for rq_value in rq_lists[i]:
            paper_ids.append(raw_df["Paper ID"][i])
            titles.append(raw_df["Title"][i])
            years.append(raw_df["Year"][i])
            venues.append(raw_df["Venue"][i])
            types.append(raw_df["Type"][i])
            problem_areas.append(rq_value)


    paper_rq_relation = pd.DataFrame(data)
    paper_rq_relation.sort_values(rq_display_name)
    return paper_rq_relation

# %%
def draw_countplot(data, column, size = (10, 8)):
    sns.countplot(y = column, data = data, orient="v", palette="coolwarm", 
              order = paper_rq1_relation[column].value_counts().index)
    ax1 = plt.gca()
    ax1.yaxis.label.set_visible(False)
    ax1.xaxis.label.set_visible(False)
    fig = plt.gcf()
    fig.set_size_inches(*size)
    plt.show()

# %%
"""
Countplot of problem areas
"""
paper_rq1_relation = create_relation_paper_RQ(raw_df, "RQ1: Problem Area", "RQ1_Problem_Area")
draw_countplot(paper_rq1_relation, "RQ1_Problem_Area", size = (10,5))

# %%
"""
Countplot of technical issues
"""
paper_rq1_relation = create_relation_paper_RQ(raw_df, "RQ1: Technical Issue", "RQ1_Technical_Issue")
draw_countplot(paper_rq1_relation, "RQ1_Technical_Issue")

# %%
"""
Creating relations between two RQs
"""

def create_relation(data, column_A_in_df, column_A_display, column_B_in_df, column_B_display):
    column_A_lists = data[column_A_in_df].apply(split_input_data)
    column_B_lists = data[column_B_in_df].apply(split_input_data)

    relations_list = []
    for i in range(len(column_A_lists)):
        column_A_values = column_A_lists[i]
        column_B_values = column_B_lists[i]
        for column_A_value in column_A_values:
            for column_B_value in column_B_values:
                relations_list.append((column_A_value, column_B_value))
    
    # Create data frame. Each column holds items from one RQ
    A, B = zip(*relations_list)
    data = {
        column_A_display : A,
        column_B_display : B
    }
    return pd.DataFrame(data)

# %%
"""
Create relation between RQ1: Problem area, and RQ1: Technical issues
"""
relation_df = create_relation(data = raw_df, column_A_in_df = "RQ1: Problem Area", column_A_display = "RQ1_Problem_Area", column_B_in_df = "RQ1: Technical Issue", column_B_display = "RQ1_Technical_Issue")

# %%
import networkx as nx

def load(df):
    G = nx.Graph()
    count = 0
    for row in df.iterrows():
        node_A = row[1][0]
        node_B = row[1][1]
        if G.has_edge(node_A, node_B):
            # we added this one before, just increase the weight by one
            G[node_A][node_B]['weight'] += 1
        else:
            # new edge. add with weight=1
            G.add_edge(node_A, node_B, weight=1)
        count += 1
        """
        if count == 5:
            break
        """
    return G

G = load(relation_df)
fig = plt.gcf()
fig.set_size_inches(10, 8)
nx.draw(G, with_labels=True)

plt.show()
